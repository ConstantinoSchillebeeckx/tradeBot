# %%
import json
import pandas as pd
from coinbase.wallet.client import Client

# %matplotlib inline

api_key = '2oEmRON5Ksv1tapy'
api_secret = '7RCSkbt6weYMlzveHRi90arugC3ywP6Z'
client = Client(api_key, api_secret)

# %%
currency_code = 'USD'  # can also use EUR, CAD, etc.

# Make the request
price = client.get_spot_price(currency=currency_code)

print 'Current bitcoin price in %s: %s' % (currency_code, price.amount)
# Out:
# Current bitcoin price in USD: 2475.00

# %%
import tradeBot


# %load_ext autoreload  
# %autoreload 2  

bot = tradeBot.tradeBot(freq=15)


bot.plot_historical_prices(columns=['ask','bid','last'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
